# %% [markdown]
# <a href="https://colab.research.google.com/github/ant-nik/LLaVA/blob/main/adsu/exam_variants.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy
from sympy.functions.elementary.hyperbolic import tanh
import random as rnd

k=rnd.choices(range(1,1000),k=22)

sympy.init_printing(use_unicode=True)

A=sympy.symbols('A')
B=sympy.symbols('B')
C=sympy.symbols('C')
D=sympy.symbols('D')
E=sympy.symbols('E')
x=sympy.symbols('x')
y=sympy.symbols('y')
u=sympy.symbols('u')
syms=[
        ['\\omega','dm','U','dm_{ж}'],
        ['dV','P','F','P_{ж}'],
        ['T','dP','I','dP_{ж}'],
        ['\\omega','v','F','v_{ж}'],
        ['dm','P','\\omega','P_{ж}'],
        ['v','\\omega','F','\\omega_{ж}'],
        ['T1','T2','I','T2ж'],
        ['Ib', 'Ub', 'Uc', 'Uж']
]
target={
    'dm':'уровня массового расхода газа, задаваемого оператором',
    'P':'уровня давления, задаваемого оператором',
    'dP':'уровня скорости изменения давления, задаваемого внешней системой управления',
    'v':'уровня скорости перемещения, задаваемой водителем ТС',
    '\\omega':'уровня скорости вращения, заданной системой верхнего уровня',
    'T2':'уровня температуры в помещении, заданной пользователем кондиционера',
    'Ub': 'уровня напряжения на клеммах системы накопления энергии'
}
sensor={
        'dP':'датчик изменения давления',
        '\\omega': 'датчик скорости вращения',
        'dm': 'датчик массового расхода',
        'dV': 'датчик объемного расхода',
        'P': 'датчик давления',
        'T': 'датчик температуры',
        'v': 'датчик скорости перемещения',
        'T1': 'датчик температуры теплоносителя',
        'T2': 'датчик температуры в помещении',
        'Ib': 'амперметр системы накопления энергии',
        'Ub': 'вольтметр системы накопления энергии'
      }
variable={
        'dP':'изменение давления газа в резервуаре',
        '\\omega': 'скорость вращения механического элемента системы',
        'dm': 'массовый расход газа в трубе',
        'dV': 'объёмный расход газа в трубе',
        'P': 'давление газа в резервуаре',
        'T': 'температура',
        'v': 'линейная скорость движения',
        'T1': 'температура теплоносителя',
        'T2': 'температура в помещении',
        'Ib': 'ток через систему накопления энергии',
        'Ub': 'напряжение на клеммах системы накопления энергии'
      }
control={
    'U':'напряжение обмотки электропривода',
    'F':'усилие исполнительного механизма',
    'I':'сила тока, протекающего через нагревательный элемент',
    '\\omega':'скорость вращения вентилятора',
    'Uc': 'сила напряжения управляющего элемента'
}
actuator={
    'U':'электропривод',
    'F':'электропривод',
    'I':'нагревательный элемент',
    '\\omega':'вентилятор',
    'Uc': 'электронный компонент, регулирующий напряжение заряда'
}
func1=[
    {'f':A*x+C,'v':[x],'p':[A, C]}
    #{'f':A*sympy.cos(B*x+C)+D,'v':[x],'p':[A,B,C,D]},
    #{'f':A*sympy.sin(B*x+C)+D,'v':[x],'p':[A,B,C,D]}
    #{'f':A*sympy.exp(-sympy.sqrt(B*B)*x*x+tanh(B)*x+tanh(C))+E,'v':[x],'p':[A,B,C,D,E]}
]
func2=[
    {'f': A*x*x+B*y+C,'v':[x,y],'p':[A,B,C]},
    {'f': A*x*x+B*y*y+C,'v':[x,y],'p':[A,B,C]},
    {'f': A*x*x*x+B*y+C,'v':[x,y],'p':[A,B,C]},
    {'f': A*x*x*x+B*y*y+C,'v':[x,y],'p':[A,B,C]},
    {'f': A*x+B*y*y+C,'v':[x,y],'p':[A,B,C]},
    {'f': A*x*x+B*y*y+C,'v':[x,y],'p':[A,B,C]},
    {'f': A*x+B*y*y*y+C,'v':[x,y],'p':[A,B,C]},
    {'f': A*x*x*x+B*y*y*y+C,'v':[x,y],'p':[A,B,C]}
    #{'f':A*x*sympy.cos(B*y+C)+D,'v':[x,y],'p':[A,B,C,D]},
    #{'f':A*x*sympy.sin(B*y+C)+D,'v':[x,y],'p':[A,B,C,D]},
    #{'f':A*x*sympy.exp(-sympy.sqrt(B*B)*y*y+tanh(B)*y+tanh(C))+E,'v':[x,y],'p':[A,B,C,D,E]}
]

students = [
            "Абрамова	Анна         ",
            "Алексеева	Екатерина    ",
            "Басин	Илья             ",
            "Баскакова	Анастасия    ",
            "Бондарев	Богдан       ",
            "Бондарь	Данила       ",
            "Варик	Александр        ",
            "Гайко	Егор             ",
            "Елагин	Владислав        ",
            "Зубрицкая	Ирина        ",
            "Касырбай	Даулет       ",
            "Кононенко	Евгений      ",
            "Кошмухамбетова	Дина     ",
            "Крючков	Артем        ",
            "Лебедев	Павел        ",
            "Лобанов	Илья         ",
            "Марченко	Владислав    ",
            "Перепелица	Вячеслав     ",
            "Подсевалов	Юрий         ",
            "Приезжева	Валерия      ",
            "Руснак	Маргарита        ",
            "Савин	Вадим            ",
            "Сидорина	Дарья        ",
            "Торопыгин	Антон        ",
            "Федюкин	Виталий      ",
            "Шишкин	Александр        "
]

quest = [
    "Понятие расширенного управления процессами (Advanced Process Control). В каких ситуациях применяются и для чего предназначено. Виды неопределенности. Общая структура адаптивных систем (название и назначение контуров, решаемые ими задачи).",
    "Основные типы адаптивных систем. Характеристика основных компонент адаптивной системы (основной контур, целевая функция, алгоритм адаптации).                                                                                                 ",
    "Характеристика современных алгоритмов ПИД-регулирования с примерами из патентов.                                                                                                                                                              ",
    "Характеристика современных пакетов прикладных программ, реализующих автонастройку ПИД-алгоритмов регулирования (примеры пакетов).                                                                                                             ",
    "Характеристика современных приборов управления (регуляторов), реализующих автонастройку ПИД-алгоритмов регулирования (+примеры устройств).                                                                                                    ",
    "Технология Advanced Process Control на примере пакета PCS7. Общая характеристика.                                                                                                                                                             ",
    "Технология Advanced Process Control на примере пакета PCS7. Мониторинг показателей качества систем управления, автонастройка комбинирование нескольких ПИД регуляторов в одном контуре управления на основе логики переключений.              ",
    "Технология Advanced Process Control на примере пакета PCS7. Схемы управления с динамическими коэффициентами на основе таблицы.                                                                                                                ",
    "Технология Advanced Process Control на примере пакета PCS7. Схема с предиктором Смита.                                                                                                                                                        ",
    "Технология Advanced Process Control на примере пакета PCS7. Схема прямой компенсации возмущений на основе модели.                                                                                                                             ",
    "Технология Advanced Process Control на примере пакета PCS7. Схемы на основе Model Predictive control. Общая характеристика.                                                                                                                   ",
    "Технология Advanced Process Control на примере пакета PCS7. Схемы на основе Model Predictive control. Пример с ректификационной колонной.                                                                                                     ",
    "Model Predictive Control на примере круиз-контроля автомобиля. Общая постановка задачи.                                                                                                                                                       ",
    "Model Predictive Control на примере круиз-контроля автомобиля. Характеристика и различия подходов к реализации.                                                                                                                               ",
    "Процесс создания моделей для цифровых двойников на примере системы. управления проскальзыванием колес автомобиля.                                                                                                                             ",
    "Структура автопилота энергокайта Makani.                                                                                                                                                                                                      ",
    "Синтез нелинейных законов управления по методу эталонной модели                                                                                                                                                                               ",
    "Синтез нелинейных законов по методу АКАР.                                                                                                                                                                                                     ",
    "Синтез нелинейных законов управления с интегральной адаптацией на основе метода АКАР.                                                                                                                                                         "
]

per_page = 3

count = 0
for i in range(1,len(students)):
    # choice varibales pair (u is always for first variable)
    vs=rnd.choice(syms)
    # select 2 functions for first equation, generate values for parameters, add unknown value and -x^3
    eq1=rnd.choice(func1);
    eq1['eq']=sympy.symbols('0')
    lc=eq1['f'].subs('x',vs[1].replace('\\',''))
    vals=rnd.choices(range(1,10),k=5);
    signs=rnd.choices([-1,1],k=5);
    idx=0
    for j in eq1['p']:
        lc=lc.subs(j,signs[idx]*vals[idx])
        idx=idx+1
    eq1['eq']=lc;
    eq1['eq']=eq1['eq']+sympy.symbols('d'+vs[1]+'_0')+rnd.choice(range(1,30))*rnd.choice([-1,1])*sympy.symbols(vs[0])

    # select 1 function for second equation, generate values for parameters, add u function and -y^3
    eq2=rnd.choice(func2);
    eq2['eq']=sympy.symbols('0')
    lc=eq2['f'].subs('x',vs[0].replace('\\',''))
    lc=lc.subs('y',vs[1].replace('\\',''))
    vals=rnd.choices(range(1,10),k=5);
    signs=rnd.choices([-1,1],k=5);
    idx=0
    for j in eq2['p']:
        lc=lc.subs(j,signs[idx]*vals[idx])
        idx=idx+1
    eq2['eq']=lc;
    eq2['eq']=eq2['eq']-0.1*sympy.symbols(vs[0])**3+30*(sympy.tanh(sympy.symbols(vs[2])))

    print(f'**Билет №{count + 1}: {students[i]}**')
    print()
    print('**Теоретический вопрос**')
    print()
    print(quest[count % len(quest)])
    print()
    print('**Практическая задача**')
    print()
    print('Система управления разрабатывается для обеспечения желаемого '+target[vs[1]]+'.')
    print('В объекте управления имеется 2 датчика и один исполнительный механизм: ')
    print('- '+sensor[vs[0]])
    print('- '+sensor[vs[1]])
    print('- '+actuator[vs[2]])
    print('\nДинамика показаний датчиков описывается следующей моделью:')
    print('\\begin{align}')
    print('\\dot {' + vs[1] + '}& =' + sympy.latex(eq1['eq'])+',\\\\')
    print('\\dot {' + vs[0] + '}& =' + sympy.latex(eq2['eq'])+',')
    print('\\end{align}')
    print('где $'+vs[0]+'$ - ' + variable[vs[0]]+', $'+vs[1]+'$ - '
          + variable[vs[1]]+', $'+vs[2]+'$ - ' + control[vs[2]]
          +', $d'+vs[1]+'_0 \\in \\left[' + str(rnd.choice(range(1,10)))
          + ';'+str((15+rnd.choice(range(1,10))))
          + '\\right]$ - неконтролируемое возмущение в системе.\n')
    print('Необходимо произвести ситнтез системы по методу АКАР с интегральной адаптацией.')
    print()
    print('##################################################################################')
    print()

    count = count + 1
# Out:
# **Билет №1: Алексеева	Екатерина    **
#
# **Теоретический вопрос**
#
# Понятие расширенного управления процессами (Advanced Process Control). В каких ситуациях применяются и для чего предназначено. Виды неопределенности. Общая структура адаптивных систем (название и назначение контуров, решаемые ими задачи).
#
# **Практическая задача**
#
# Система управления разрабатывается для обеспечения желаемого уровня давления, задаваемого оператором.
# В объекте управления имеется 2 датчика и один исполнительный механизм:
# - датчик объемного расхода
# - датчик давления
# - электропривод
#
# Динамика показаний датчиков описывается следующей моделью:
# \begin{align}
# \dot {P}& =2 P + dP_{0} + 23 dV - 9,\\
# \dot {dV}& =- 4 P^{3} + 3.9 dV^{3} + 30 \tanh{\left(F \right)} + 4,
# \end{align}
# где $dV$ - объёмный расход газа в трубе, $P$ - давление газа в резервуаре, $F$ - усилие исполнительного механизма, $dP_0 \in \left[1;22\right]$ - неконтролируемое возмущение в системе.
#
# ...

# %%
|vs=syms[5]
# select 2 functions for first equation, generate values for parameters, add unknown value and -x^3
eq1=rnd.choice(func1);
eq1['eq']=sympy.symbols('0')
lc=eq1['f'].subs('x',vs[1].replace('\\',''))
vals=rnd.choices(range(1,10),k=5);
signs=rnd.choices([-1,1],k=5);
idx=0
for j in eq1['p']:
    lc=lc.subs(j,signs[idx]*vals[idx])
    idx=idx+1
eq1['eq']=lc;
eq1['eq']=eq1['eq']+sympy.symbols('d'+vs[1]+'_0')+rnd.choice(range(1,30))*rnd.choice([-1,1])*sympy.symbols(vs[0])-0.1*sympy.symbols(vs[1])**3

# select 1 function for second equation, generate values for parameters, add u function and -y^3
eq2=rnd.choice(func2);
eq2['eq']=sympy.symbols('0')
lc=eq2['f'].subs('x',vs[0].replace('\\',''))
lc=lc.subs('y',vs[1].replace('\\',''))
vals=rnd.choices(range(1,10),k=5);
signs=rnd.choices([-1,1],k=5);
idx=0
for j in eq2['p']:
    lc=lc.subs(j,signs[idx]*vals[idx])
    idx=idx+1
eq2['eq']=lc;
eq2['eq']=eq2['eq']-0.1*sympy.symbols(vs[0])**3+30*(sympy.tanh(sympy.symbols(vs[2])))
print(eq1)
print(eq2)
# Out:
#   File "<ipython-input-2-7449b7fdcfe4>", line 1
#     |vs=syms[5]
#     ^
# SyntaxError: invalid syntax

# %%
eq2['f'].subs('x',vs[0]).subs('y',vs[1].replace('\\',' '))

# %%
vs

# %%
# !pip install sympy

# %%
import numpy
import matplotlib.pyplot as plt
import math

ls = numpy.linspace(-10.0,10.0,1000)
exp = [math.exp(- 3*x*x + 0.5*x + 1  ) for x in ls]
plt.plot(ls, exp)
